# %%
# https://blog.csdn.net/zyaiwmy/article/details/70241624
# https://blog.csdn.net/ge341204/article/details/81046101

# https://blog.csdn.net/hellolijunshy/article/details/82527643
# https://blog.csdn.net/s1164548515/article/details/89451185
import tushare as ts

import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# %%
import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %matplotlib notebook

google_start = dt.datetime(2004,8,20)
tesla_start = dt.datetime(2010,6,21)
amazon_start = dt.datetime(1997,5,16)
brk_start = dt.datetime(1996,5,10)

apple_start = dt.datetime(1980,12,12)
fb_start = dt.datetime(2012,5,18)
baba_start = dt.datetime(2014,9,19)
jd_start = dt.datetime(2014,5,23)

pdd_start = dt.datetime(2018,7,27)
bilibili_start = dt.datetime(2018,5,29)
meituan_start = dt.datetime(2018,11,23)

end = dt.datetime.today()


# 1000
start = dt.datetime(2012,1,1)
googleA=web.get_data_yahoo('GOOGL',start,end)
googleC=web.get_data_yahoo('GOOG',start,end)
tesla=web.get_data_yahoo('TSLA',start,end)
amazon=web.get_data_yahoo('AMZN',start,end)

# stocks.plot(secondary_y = ["AAPL", "FB", "BABA", "JD", "PDD", "BILI", "3690.HK"], grid = True)
stocks1000 = pd.DataFrame({
                    "GOOG": googleA["Adj Close"],
#                     "GOOGL": googleC["Adj Close"],
                    "TSLA": tesla["Adj Close"],
                    "AMZN": amazon["Adj Close"]
                    })
stocks1000.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 200
start = dt.datetime(2015,1,1)
apple=web.get_data_yahoo('AAPL',start,end)
facebook=web.get_data_yahoo('FB',start,end)
alibaba=web.get_data_yahoo('BABA',start,end)
brk=web.get_data_yahoo('BRK-B',start,end)
# 50
jingdong=web.get_data_yahoo('JD',start,end)

stocks100 = pd.DataFrame({
                    "AAPL": apple["Adj Close"],     
                    "FB": facebook["Adj Close"],         
                    "BABA": alibaba["Adj Close"],                    
                    "BRK.B": brk["Adj Close"],
                    "JD": jingdong["Adj Close"]
                    })

# stocks100.plot(grid = True)
# stocks100.plot(color = ['#696969', '#1E90FF','#FF4500','r','#BA55D3'], secondary_y = ["JD"], grid = True)
# stocks100.plot(subplots=True, layout=(2, -1), sharex=True);   # 5 个plots
f, ax = plt.subplots(2,1)
stocks100[['AAPL','FB','BABA','BRK.B', 'JD']].plot(color = ['#696969', '#1E90FF','#FF4500','#BA55D3','r'], 
                                                   subplots=True, sharex=True, ax=[ax[0],ax[0],ax[0],ax[0],ax[1]], grid=True)
# stocks100.iloc[:, :4].plot(color = ['#696969', '#1E90FF','#FF4500','#BA55D3'])
# stocks100.iloc[:, 4].plot(color = ['r'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/Apps/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py:62: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   plot_obj.generate()
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11aa30ad0>,
# ...
#       dtype=object)

# %%
# 50
start = dt.datetime(2018,7,1)
jingdong=web.get_data_yahoo('JD',start,end)
pinduoduo=web.get_data_yahoo('PDD',start,end)
bilibili=web.get_data_yahoo('BILI',start,end)
meituan=web.get_data_yahoo("3690.HK",start,end)

stocks50 = pd.DataFrame({
                    "JD": jingdong["Adj Close"],
                    "PDD": pinduoduo["Adj Close"],
                    "BILI": bilibili["Adj Close"],
                    "MeiTuan": meituan["Adj Close"]/7.7
                      })   
stocks50.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(stocks1000.iloc[-1])
print(stocks100.iloc[-1])
print(stocks50.iloc[-1])
# Out:
# GOOG    1295.739990
# TSLA     703.479980
# AMZN    1901.089966
# Name: 2020-03-06 00:00:00, dtype: float64
# AAPL     289.029999
# FB       181.089996
# BABA     204.639999
# BRK.B    205.979996
# JD        42.160000
# Name: 2020-03-06 00:00:00, dtype: float64
# JD         42.160000
# PDD        36.759998
# BILI       26.680000
# MeiTuan    13.077922
# Name: 2020-03-06 00:00:00, dtype: float64

# %%
import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# .ss 表示上证 .sz表示深证
start = dt.datetime(2008,11,23)
end = dt.datetime.today()
# https://www.cnblogs.com/hhh5460/p/5120079.html
geli = web.get_data_yahoo("000651.SZ",start,end)
meidi = web.get_data_yahoo("000333.SZ",start,end)
shihua = web.get_data_yahoo("600028.ss",start,end)
shiyou = web.get_data_yahoo("601857.ss",start,end)
maotai = web.get_data_yahoo("600519.ss",start,end)

china = pd.DataFrame({"GELI": geli["Adj Close"], "MEDI": meidi["Adj Close"]})
china.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(china.iloc[-1])
# Out:
# GELI    61.430000
# MEDI    55.810001
# Name: 2020-03-06 00:00:00, dtype: float64

# %%
# - 'SP500' for S&P 500,
# - 'DOW' for Dow Jones Industrial Average,
# - 'NASDAQ' for NASDAQ Composite Index
import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

start = dt.datetime(1990,8,20)
end = dt.datetime.today()

sp500 = web.get_data_yahoo("^GSPC",start,end)   # ^SP500TR"
dow = web.get_data_yahoo("^DJI",start,end)  
nasdaq = web.get_data_yahoo("^IXIC",start,end)

usIndex = pd.DataFrame({"SP500": sp500["Adj Close"], "DOW": dow["Adj Close"], "NASDAQ": nasdaq["Adj Close"]})
usIndex.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
usIndex.iloc[-14:]
# Out:
#                   SP500           DOW       NASDAQ
# Date
# 2020-02-18  3370.290039  29232.189453  9732.740234
# 2020-02-19  3386.149902  29348.029297  9817.179688
# 2020-02-20  3373.229980  29219.980469  9750.969727
# 2020-02-21  3337.750000  28992.410156  9576.589844
# 2020-02-24  3225.889893  27960.800781  9221.280273
# 2020-02-25  3128.209961  27081.359375  8965.610352
# 2020-02-26  3116.389893  26957.589844  8980.780273
# 2020-02-27  2978.760010  25766.640625  8566.480469
# 2020-02-28  2954.219971  25409.359375  8567.370117
# 2020-03-02  3090.229980  26703.320312  8952.169922
# 2020-03-03  3003.370117  25917.410156  8684.089844
# 2020-03-04  3130.120117  27090.859375  9018.089844
# 2020-03-05  3023.939941  26121.279297  8738.589844
# 2020-03-06  2972.370117  25864.779297  8575.618164

# %%
import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import tushare as ts 
# %matplotlib notebook

start = dt.datetime(2008,8,20)
end = dt.datetime.today()

sz = web.get_data_yahoo("000001.ss",start,end)  # 上证综指
#sz = web.get_data_yahoo("000016.ss",start,end)  # 上证综指
#sz = web.get_data_yahoo("510050.ss",start,end)  # 上证50ETF 04年
#sz = web.get_data_yahoo("510300.ss",start,end)  # 沪深300
hs = web.get_data_yahoo("000300.ss",start,end)  # 沪深300 基金
#zz = web.get_data_yahoo("510500.ss",start,end)  # 中证500
zz = web.get_data_yahoo("000905.ss",start,end)  # 中证500

chinaIndex = pd.DataFrame({"ShangZheng50": sz["Adj Close"], "HuShen300": sz["Adj Close"], "ZhongZheng500": zz["Adj Close"]})
chinaIndex.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
chinaIndex.iloc[-5:]
# Out:
#             ShangZheng50    HuShen300  ZhongZheng500
# Date
# 2020-03-02   2970.930908          NaN            NaN
# 2020-03-03   2992.896973          NaN            NaN
# 2020-03-04   3011.666016          NaN            NaN
# 2020-03-05   3071.677002          NaN            NaN
# 2020-03-06   3034.511230  4138.507324    5763.860352

# %%
# Khai Liang portfolio
# (INVESTED)
# FB     17.32(9.56)
# BABA   18.27(9.56)
# JD     13.81(7.71)
# DIS    8.52(4.78)
# SBUX   11.32(4.78) 
# APPL   6.46(2.39)
# NFLX   3.72(2.39)  
# SHOP   16.83(3.34)
# FXI    (2.39) ETF

# 高风险投资 <= [5%, 10%]
# 关注long term，稳定产业：AT&T 即便疫情，电话行业还是可以赚钱的
# >>> 水、电、


# .ss 表示上证 .sz表示深证
start = dt.datetime(2000,11,23)
end = dt.datetime.today()
# https://www.cnblogs.com/hhh5460/p/5120079.html
maotai = web.get_data_yahoo("600519.ss",start,end)

china = pd.DataFrame({"MaoTai": maotai["Adj Close"]})
china.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import pandas_datareader.data as web   
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# '上证指数'=>'000001.SS',
# '深圳成指'=>'399001.SZ',
# '香港恒生'=>'0011.hk',

ShangZheng = web.get_data_yahoo("000001.ss",start,end)

china = pd.DataFrame({"ShangZheng": ShangZheng["Adj Close"]})
china.plot(grid = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
start = dt.datetime(2008,8,20)
end = dt.datetime.today()

sz = ts.get_hist_data('000905',start,end) 
sz.iloc[-2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-d7da865f2031> in <module>
# ----> 1 sz = ts.get_hist_data('000905',start,end)
#       2 sz.iloc[-2]
#
# /Users/Apps/anaconda3/lib/python3.7/site-packages/tushare/stock/trading.py in get_hist_data(code, start, end, ktype, retry_count, pause)
#      93                 df[col] = df[col].astype(float)
#      94             if start is not None:
# ---> 95                 df = df[df.date >= start]
#      96             if end is not None:
#      97                 df = df[df.date <= end]
#
# /Users/Apps/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ...
